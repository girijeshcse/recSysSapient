# %%
import pandas as pd 
import numpy as np

# %%
# !ls
# Out:
# Data.zip
# Problem Statement.docx
# Untitled.ipynb
# shared_articles.csv
# users_interactions.csv

# %%
df_article = pd.read_csv('shared_articles.csv', low_memory=False)
df_article.head()
# Out:
#     timestamp        eventType     contentId authorPersonId authorSessionId  \
# 0  1459192779  CONTENT REMOVED  -6.45131E+18    4.34031E+18     8.94034E+18
# 1  1459193988   CONTENT SHARED  -4.11035E+18    4.34031E+18     8.94034E+18
# 2  1459194146   CONTENT SHARED  -7.29229E+18    4.34031E+18     8.94034E+18
# 3  1459194474   CONTENT SHARED  -6.15185E+18    3.89164E+18    -1.45753E+18
# 4  1459194497   CONTENT SHARED   2.44803E+18    4.34031E+18     8.94034E+18
#
#   authorUserAgent authorRegion authorCountry contentType  \
# 0             NaN          NaN           NaN        HTML
# 1             NaN          NaN           NaN        HTML
# 2             NaN          NaN           NaN        HTML
# 3             NaN          NaN           NaN        HTML
# 4             NaN          NaN           NaN        HTML
#
#                                                  url  ... Unnamed: 617  \
# 0  http://www.nytimes.com/2016/03/28/business/dea...  ...          NaN
# ...

# %%
df_article.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3146 entries, 0 to 3145
# Columns: 627 entries, timestamp to Unnamed: 626
# dtypes: object(627)
# memory usage: 15.0+ MB

# %%
sum(df_article.isna().sum() == 3145)
# Out:
# 250

# %%
df_article.isna().sum(axis=1)
# Out:
# 0       617
# 1       617
# 2       617
# 3       617
# 4       617
#        ...
# 3141    614
# 3142    614
# 3143    614
# 3144    614
# 3145    614
# Length: 3146, dtype: int64

# %%
df_user_intection = pd.read_csv("users_interactions.csv")
df_user_intection.head()
# Out:
#     timestamp eventType     contentId      personId     sessionId  \
# 0  1465413032      VIEW -3.499920e+18 -8.845300e+18  1.264200e+18
# 1  1465412560      VIEW  8.890720e+18 -1.032020e+18  3.621740e+18
# 2  1465416190      VIEW  3.105150e+17 -1.130270e+18  2.631860e+18
# 3  1465413895    FOLLOW  3.105150e+17  3.442810e+17 -3.167640e+18
# 4  1465412290      VIEW -7.820640e+18 -4.453370e+17  5.611480e+18
#
#                                            userAgent userRegion userCountry
# 0                                                NaN        NaN         NaN
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...         NY          US
# 2                                                NaN        NaN         NaN
# 3                                                NaN        NaN         NaN
# 4                                                NaN        NaN         NaN

# %%
df_user_intection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72312 entries, 0 to 72311
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    72312 non-null  int64
#  1   eventType    72312 non-null  object
#  2   contentId    72312 non-null  float64
#  3   personId     72312 non-null  float64
#  4   sessionId    72312 non-null  float64
#  5   userAgent    56918 non-null  object
#  6   userRegion   56907 non-null  object
#  7   userCountry  56918 non-null  object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 4.4+ MB
